# %% [markdown]
# # Title

# %% [markdown]
# ## Summary

# %% [markdown]
# #### Objective

# %% [markdown]
# #### Methodology

# %% [markdown]
# #### Results

# %% [markdown]
# #### Discussion

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Methodology

# %% [markdown]
# ### Data

# %% [markdown]
# #### Data source

# %% [markdown]
# #### Data verification

# %% [markdown]
# #### Data statistics

# %% [markdown]
# #### Data visualization

# %% [markdown]
# #### Feature engineering

# %% [markdown]
# #### Feature selection

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Types

# %% [markdown]
# #### Baseline

# %% [markdown]
# #### Model A

# %% [markdown]
# #### Model B

# %% [markdown]
# #### Model C

# %% [markdown]
# ### Tuning

# %% [markdown]
# #### Model A

# %% [markdown]
# #### Model B

# %% [markdown]
# #### Model C

# %% [markdown]
# ### Optimal evaluation metric

# %% [markdown]
# ### Optimal model

# %% [markdown]
# - model evaluation
# - training speed
# - prediction speed
# - interpretability

# %% [markdown]
# ### Comparison

# %% [markdown]
# ## Discussion

# %% [markdown]
# ### Interpretations

# %% [markdown]
# ### Implications

# %% [markdown]
# ### Limitations

# %% [markdown]
# ### Recommendations
